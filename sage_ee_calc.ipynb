# %%
R_ring_fast.<S, L_1, L_2, H_1, H_2> = PolynomialRing(QQ, order='lex')

alpha_1 = 2
alpha_2 = 2
beta_1 = QQ(8)/1000
beta_2 = QQ(8)/1000
gamma_1 = QQ(1)/21
gamma_2 = QQ(1)/21
iota = QQ(1)/90
N_0 = QQ(300)

D = alpha_1 + alpha_2
R_var_sub = N_0 - S - L_1 - L_2 - H_1 - H_2

dSdt   = - beta_1*S*H_1 - beta_2*S*H_2 + iota*R_var_sub
dL_1dt = (beta_1*S*H_1 - alpha_1*L_1)*D - alpha_2*beta_2*L_1*H_2
dL_2dt = (beta_2*S*H_2 - alpha_2*L_2)*D - alpha_1*beta_1*L_2*H_1
dH_1dt = (alpha_1*L_1 - gamma_1*H_1)*D + alpha_1*beta_1*L_2*H_1
dH_2dt = (alpha_2*L_2 - gamma_2*H_2)*D + alpha_2*beta_2*L_1*H_2

I = ideal([dSdt, dL_1dt, dL_2dt, dH_1dt, dH_2dt])

# # 2. Convert to lex order using the change_ring tool (FGLM algorithm)
# R_ring_solve.<S, L_1, L_2, H_1, H_2> = PolynomialRing(K, order='lex')
# I_lex = I_fast.change_ring(R_ring_solve)

gb = I.groebner_basis()
#gb = I.variety(Ring=QQbar)
print(len(gb))
# The last element of 'gb' will be a polynomial purely in H_2.
# You can view the triangular equations here:
print("Actual Ring:", I.ring())
print("Dimension:", I.dimension())
print("Groebner Basis:")
for p in gb:
    print(p)

for poly in gb:
    print(poly)
    print("-" * 20)
# Out:
# 6
# Actual Ring: Multivariate Polynomial Ring in S, L_1, L_2, H_1, H_2 over Rational Field
# Dimension: 0
# Groebner Basis:
# S + 223/42*H_1 - 884433372188618992711279/23355557963448076051537837500000000*H_2^5 + 1094059751475555735329430191/7847467475718553553316713400000000*H_2^4 - 80772055494949506025194761099/784746747571855355331671340000000*H_2^3 + 30555199448088503859216129721/87194083063539483925741260000*H_2^2 - 4845231904250537058673233817/348776332254157935702965040*H_2 - 300
# L_1 - 1/42*H_1 + 30943881429446054863491599/980933434464819194164589175000000000*H_2^5 - 1093667574091325106927391973/9416960970862264263980056080000000*H_2^4 + 403865527347026503470933493117/4708480485431132131990028040000000*H_2^3 - 152777676301971336486926517671/523164498381236903554447560000*H_2^2 + 33452475280055948009313304079/2092657993524947614217790240*H_2
# L_2 + 6202320202475942830382119/980933434464819194164589175000000000*H_2^5 - 156574376913815553905660183/6726400693473045902842897200000000*H_2^4 + 80766805622670532680235073477/4708480485431132131990028040000000*H_2^3 - 6110704077311937333674052131/104632899676247380710889512000*H_2^2 + 6680108396936283160734418663/2092657993524947614217790240*H_2
# H_1^2 - 12350/223*H_1 + 14856546950038390588662803/289349412547162275527385431250000*H_2^5 - 2625042143527760225158300117/13888771802263789225314500700000*H_2^4 + 193758305607927550189065161449/1388877180226378922531450070000*H_2^3 - 14700217092346435822529108041/30863937338363976056254446*H_2^2 + 402365728315449538080452658725/15431968669181988028127223*H_2
# H_1*H_2 + 93097711635718079257/43251033265644585280625625000*H_2^5 - 16437803454850800506927/2076049596750940093470030000*H_2^4 + 1209143006076916346328671/207604959675094009347003000*H_2^3 - 436224349379154078485058/23067217741677112149667*H_2^2 + 23861447091268453682499250/23067217741677112149667*H_2
# H_2^6 - 833487625/246642*H_2^5 + 3367398266875/2096457*H_2^4 - 536012568437500/63529*H_2^3 - 93910679531250000/41107*H_2^2 + 106777115859375000000/698819*H_2
# S + 223/42*H_1 - 884433372188618992711279/23355557963448076051537837500000000*H_2^5 + 1094059751475555735329430191/7847467475718553553316713400000000*H_2^4 - 80772055494949506025194761099/784746747571855355331671340000000*H_2^3 + 30555199448088503859216129721/87194083063539483925741260000*H_2^2 - 4845231904250537058673233817/348776332254157935702965040*H_2 - 300
# --------------------
# L_1 - 1/42*H_1 + 30943881429446054863491599/980933434464819194164589175000000000*H_2^5 - 1093667574091325106927391973/9416960970862264263980056080000000*H_2^4 + 403865527347026503470933493117/4708480485431132131990028040000000*H_2^3 - 152777676301971336486926517671/523164498381236903554447560000*H_2^2 + 33452475280055948009313304079/2092657993524947614217790240*H_2
# --------------------
# L_2 + 6202320202475942830382119/980933434464819194164589175000000000*H_2^5 - 156574376913815553905660183/6726400693473045902842897200000000*H_2^4 + 80766805622670532680235073477/4708480485431132131990028040000000*H_2^3 - 6110704077311937333674052131/104632899676247380710889512000*H_2^2 + 6680108396936283160734418663/2092657993524947614217790240*H_2
# --------------------
# H_1^2 - 12350/223*H_1 + 14856546950038390588662803/289349412547162275527385431250000*H_2^5 - 2625042143527760225158300117/13888771802263789225314500700000*H_2^4 + 193758305607927550189065161449/1388877180226378922531450070000*H_2^3 - 14700217092346435822529108041/30863937338363976056254446*H_2^2 + 402365728315449538080452658725/15431968669181988028127223*H_2
# --------------------
# H_1*H_2 + 93097711635718079257/43251033265644585280625625000*H_2^5 - 16437803454850800506927/2076049596750940093470030000*H_2^4 + 1209143006076916346328671/207604959675094009347003000*H_2^3 - 436224349379154078485058/23067217741677112149667*H_2^2 + 23861447091268453682499250/23067217741677112149667*H_2
# --------------------
# H_2^6 - 833487625/246642*H_2^5 + 3367398266875/2096457*H_2^4 - 536012568437500/63529*H_2^3 - 93910679531250000/41107*H_2^2 + 106777115859375000000/698819*H_2
# --------------------

# %%
print("Solutions = ", I.variety())
# Out:
# Solutions =  [{H_2: 0, H_1: 0, L_2: 0, L_1: 0, S: 300}, {H_2: 0, H_1: 12350/223, L_2: 0, L_1: 6175/4683, S: 125/21}, {H_2: 4940/89, H_1: 0, L_2: 1235/1869, L_1: 0, S: 125/21}]

# %%
PD = I.primary_decomposition()
for Q in PD:
    print(Q.dimension())
    print(Q.gens())
    print('---')
# Out:
# 0
# [222*H_2^2 - 737875*H_2 - 242692500, H_1 - H_2 + 7200, 126*L_2 + 222*H_2 - 808975, 126*L_1 + 1110*H_2 - 4023275, 21*S - 125]
# ---
# 0
# [17*H_2^2 + 42750000, H_1 + H_2, 420*L_2 + 17*H_2 - 142500, 84*L_1 - 17*H_2 - 5700, 105*S + 17*H_2 + 11250]
# ---
# 0
# [1111*H_2 - 61750, H_1, 23331*L_2 - 6175, L_1, 21*S - 125]
# ---
# 0
# [H_2, H_1, L_2, L_1, S - 300]
# ---
# 0
# [H_2, 223*H_1 - 12350, L_2, 4683*L_1 - 6175, 21*S - 125]
# ---

# %%
R_ring_fast.<S, L_1, H_1> = PolynomialRing(QQ, order='lex')

alpha_1 = 2
alpha_2 = 2
beta_1 = QQ(8)/1000
beta_2 = QQ(8)/1000
gamma_1 = QQ(1)/21
gamma_2 = QQ(1)/21
iota = QQ(1)/90
N_0 = QQ(300)

D = 2*alpha_1
R_var_sub = N_0 - S - L_1 - H_1

dSdt   = - beta_1*S*H_1 - beta_1*S*H_1 + iota*R_var_sub
dL_1dt = (beta_1*S*H_1 - alpha_1*L_1)*D - alpha_1*beta_1*L_1*H_1
#dL_2dt = (beta_2*S*H_2 - alpha_2*L_2)*D - alpha_1*beta_1*L_2*H_1
dH_1dt = (alpha_1*L_1 - gamma_1*H_1)*D + alpha_1*beta_1*L_1*H_1
#dH_2dt = (alpha_2*L_2 - gamma_2*H_2)*D + alpha_2*beta_2*L_1*H_2

I = ideal([dSdt, dL_1dt, dH_1dt])

# # 2. Convert to lex order using the change_ring tool (FGLM algorithm)
# R_ring_solve.<S, L_1, L_2, H_1, H_2> = PolynomialRing(K, order='lex')
# I_lex = I_fast.change_ring(R_ring_solve)

gb = I.groebner_basis()
#gb = I.variety(Ring=QQbar)
print(len(gb))
# The last element of 'gb' will be a polynomial purely in H_2.
# You can view the triangular equations here:
print("Actual Ring:", I.ring())
print("Dimension:", I.dimension())
print("Groebner Basis:")
for p in gb:
    print(p)

for poly in gb:
    print(poly)
    print("-" * 20)
# Out:
# 3
# Actual Ring: Multivariate Polynomial Ring in S, L_1, H_1 over Rational Field
# Dimension: 0
# Groebner Basis:
# S + 67/3500*H_1^2 + 1261/140*H_1 - 300
# L_1 - 67/3500*H_1^2 + 79/140*H_1
# H_1^3 + 31525/67*H_1^2 - 3087500/201*H_1
# S + 67/3500*H_1^2 + 1261/140*H_1 - 300
# --------------------
# L_1 - 67/3500*H_1^2 + 79/140*H_1
# --------------------
# H_1^3 + 31525/67*H_1^2 - 3087500/201*H_1
# --------------------

# %%
print("Solutions = ", I.variety())
# Out:
# Solutions =  [{H_1: 0, L_1: 0, S: 300}]

# %%
R_ring_fast.<S, L_1, L_2, H_1, H_2> = PolynomialRing(QQ, order='lex')

alpha_1 = 2
alpha_2 = 2
beta_1 = QQ(8)/1000
beta_2 = QQ(8)/1000
gamma_1 = QQ(1)/21
gamma_2 = QQ(1)/21
iota = 0
N_0 = QQ(300)
mu = QQ(1)/30000
Lambda = QQ(1)/100

D = alpha_1 + alpha_2
R_var_sub = N_0 - S - L_1 - L_2 - H_1 - H_2

dSdt   = Lambda - beta_1*S*H_1 - beta_2*S*H_2 + iota*R_var_sub - mu*S
dL_1dt = (beta_1*S*H_1 - alpha_1*L_1)*D - alpha_2*beta_2*L_1*H_2 - mu*L_1
dL_2dt = (beta_2*S*H_2 - alpha_2*L_2)*D - alpha_1*beta_1*L_2*H_1 - mu*L_2
dH_1dt = (alpha_1*L_1 - gamma_1*H_1)*D + alpha_1*beta_1*L_2*H_1 - mu*H_1
dH_2dt = (alpha_2*L_2 - gamma_2*H_2)*D + alpha_2*beta_2*L_1*H_2 - mu*H_2

I = ideal([dSdt, dL_1dt, dL_2dt, dH_1dt, dH_2dt])

# # 2. Convert to lex order using the change_ring tool (FGLM algorithm)
# R_ring_solve.<S, L_1, L_2, H_1, H_2> = PolynomialRing(K, order='lex')
# I_lex = I_fast.change_ring(R_ring_solve)


#I_sat = I.saturation(L_1 * L_2 * H_1 * H_2)[0]
#print("Saturated dimension:", I_sat.dimension())
#gb_endemic = I_sat.groebner_basis()
#for p in gb_endemic:
#    print(p)


gb = I.groebner_basis()
#gb = I.variety(Ring=QQbar)
#print(len(gb))
# The last element of 'gb' will be a polynomial purely in H_2.
# You can view the triangular equations here:
#print("Actual Ring:", I.ring())
#print("Dimension:", I.dimension())
#print("Groebner Basis:")
for p in gb:
    print(p)

for poly in gb:
    print(poly)
    print("-" * 20)
# Out:
# S + 9601720007/6720000*H_1 - 16282995468459133682994914965822411606616479055062549939929264/705403707716671766364164130716187345983080146299312701236606729495625*H_2^5 + 898848932273449003623932163505924859726033716271205596975201/403087832980955295065236646123535626276045797885321543563775273997500*H_2^4 - 19155646969541634168863722444006743385512535216866718472623737477992807/3385937797040024478547987827437699260718784702236700965935712301579000000*H_2^3 + 822012466047157201405687260739899830723293500846472355371444849274677589/464357183594060499915152616334313041470004759163890418185469115645120000000*H_2^2 + 123850757527303251192504972064738276345130092828227430251580053859540383101871731/86680007604224626650828488382405101074400888377259544727954234920422400000000*H_2 - 300
# L_1 - 40007/1680000*H_1 + 15635025642436773686286763937884790268218946291859269724482473317056/338594485107710164526565146907900642259224453303816395906272466764629495625*H_2^5 - 1508998228642447539647860867623779458821869824122816620044841130407/338594485107710164526565146907900642259224453303816395906272466764629495625*H_2^4 + 4596370870632636281737695547705470167048043549838397330637538924687840112807/406313382129252197431878176289480770711069343964579675087526960117555394750000*H_2^3 - 1380689258364398715854711382536564768883671955645535423517535492546495053303123/390060846844082109534603049237901539882626570205996488084025881712853178960000000*H_2^2 + 370520314751148547952569108422672509735304898814722134334585180781060068955467/1485946083215550893465154473287243961457625029356177097462955739858488300800000000*H_2
# L_2 + 25005425262378618914557127641846565289809791935643274256610357248/541751176172336263242504235052641027614759125286106233450035946823407193*H_2^5 - 12089123805910936213372612554250180890652972358275584673848104448/2708755880861681316212521175263205138073795626430531167250179734117035965*H_2^4 + 153278627679810588698368669638007022158045295559761480098010922949539508/13543779404308406581062605876316025690368978132152655836250898670585179825*H_2^3 - 2877663295086066272851682611167341336761269313027328366327097502354930351/812626764258504394863756352578961541422138687929159350175053920235110789500*H_2^2 - 1021276253110578470748963447613235879805355515455471013114542545697694151731/43340094093786901059400338804211282209180730022888498676002875745872575440000*H_2
# H_1^2 - 474238279993/2304412801680*H_1 - 1198951143273055023271729144328589575424/349694565147742868719690901914113551648000072281715*H_2^5 - 387114745597364198938166968981819418972/349694565147742868719690901914113551648000072281715*H_2^4 + 862316680773177274491158970789731871899024188655927714401/1007300790755474284043229182329385605358529034669436716731601500*H_2^3 - 967009014669073908009351220988807779960991192963621999511873213589/967008759125255312681500015036210181144187873282659248062337440000*H_2^2 + 5306834038619112265263221735593526252497823651504962266415656563467/25786900243340141671506667067632271497178343287537579948328998400000*H_2
# H_1*H_2 + 26579838028844051952501177820111190251548781591796717184/3290512922293512612777442009171719398171802431716910559704287951*H_2^5 - 1995791562169061953132759049514203044181311785814088678416/806175665961910590130473292247071252552091595770643087127550547995*H_2^4 + 38288189770810675126370016031705691061718887359793525650000546399/19348215983085854163131359013929710061250198298495434091061213151880*H_2^3 + 23203676039813097341855640678652679626302534080093525689756817905893599/23217859179703024995757630816715652073500237958194520909273455782256000*H_2^2 - 23885814956184388236429638658431494404443120898508745179086259869599/116089295898515124978788154083578260367501189790972604546367278911280*H_2
# H_2^6 + 460601857652807/921765120672*H_2^5 + 9808058434683581811848792280343/40043635996654739669580800*H_2^4 + 21185666812352230814408046402077130401/172988507505548475372589056000*H_2^3 - 1570325023842916533493017257071837711657/41517241801331634089421373440000*H_2^2 + 215473669792643924853548094787159657/83034483602663268178842746880*H_2
# S + 9601720007/6720000*H_1 - 16282995468459133682994914965822411606616479055062549939929264/705403707716671766364164130716187345983080146299312701236606729495625*H_2^5 + 898848932273449003623932163505924859726033716271205596975201/403087832980955295065236646123535626276045797885321543563775273997500*H_2^4 - 19155646969541634168863722444006743385512535216866718472623737477992807/3385937797040024478547987827437699260718784702236700965935712301579000000*H_2^3 + 822012466047157201405687260739899830723293500846472355371444849274677589/464357183594060499915152616334313041470004759163890418185469115645120000000*H_2^2 + 123850757527303251192504972064738276345130092828227430251580053859540383101871731/86680007604224626650828488382405101074400888377259544727954234920422400000000*H_2 - 300
# --------------------
# L_1 - 40007/1680000*H_1 + 15635025642436773686286763937884790268218946291859269724482473317056/338594485107710164526565146907900642259224453303816395906272466764629495625*H_2^5 - 1508998228642447539647860867623779458821869824122816620044841130407/338594485107710164526565146907900642259224453303816395906272466764629495625*H_2^4 + 4596370870632636281737695547705470167048043549838397330637538924687840112807/406313382129252197431878176289480770711069343964579675087526960117555394750000*H_2^3 - 1380689258364398715854711382536564768883671955645535423517535492546495053303123/390060846844082109534603049237901539882626570205996488084025881712853178960000000*H_2^2 + 370520314751148547952569108422672509735304898814722134334585180781060068955467/1485946083215550893465154473287243961457625029356177097462955739858488300800000000*H_2
# --------------------
# L_2 + 25005425262378618914557127641846565289809791935643274256610357248/541751176172336263242504235052641027614759125286106233450035946823407193*H_2^5 - 12089123805910936213372612554250180890652972358275584673848104448/2708755880861681316212521175263205138073795626430531167250179734117035965*H_2^4 + 153278627679810588698368669638007022158045295559761480098010922949539508/13543779404308406581062605876316025690368978132152655836250898670585179825*H_2^3 - 2877663295086066272851682611167341336761269313027328366327097502354930351/812626764258504394863756352578961541422138687929159350175053920235110789500*H_2^2 - 1021276253110578470748963447613235879805355515455471013114542545697694151731/43340094093786901059400338804211282209180730022888498676002875745872575440000*H_2
# --------------------
# H_1^2 - 474238279993/2304412801680*H_1 - 1198951143273055023271729144328589575424/349694565147742868719690901914113551648000072281715*H_2^5 - 387114745597364198938166968981819418972/349694565147742868719690901914113551648000072281715*H_2^4 + 862316680773177274491158970789731871899024188655927714401/1007300790755474284043229182329385605358529034669436716731601500*H_2^3 - 967009014669073908009351220988807779960991192963621999511873213589/967008759125255312681500015036210181144187873282659248062337440000*H_2^2 + 5306834038619112265263221735593526252497823651504962266415656563467/25786900243340141671506667067632271497178343287537579948328998400000*H_2
# --------------------
# H_1*H_2 + 26579838028844051952501177820111190251548781591796717184/3290512922293512612777442009171719398171802431716910559704287951*H_2^5 - 1995791562169061953132759049514203044181311785814088678416/806175665961910590130473292247071252552091595770643087127550547995*H_2^4 + 38288189770810675126370016031705691061718887359793525650000546399/19348215983085854163131359013929710061250198298495434091061213151880*H_2^3 + 23203676039813097341855640678652679626302534080093525689756817905893599/23217859179703024995757630816715652073500237958194520909273455782256000*H_2^2 - 23885814956184388236429638658431494404443120898508745179086259869599/116089295898515124978788154083578260367501189790972604546367278911280*H_2
# --------------------
# H_2^6 + 460601857652807/921765120672*H_2^5 + 9808058434683581811848792280343/40043635996654739669580800*H_2^4 + 21185666812352230814408046402077130401/172988507505548475372589056000*H_2^3 - 1570325023842916533493017257071837711657/41517241801331634089421373440000*H_2^2 + 215473669792643924853548094787159657/83034483602663268178842746880*H_2
# --------------------

# %%
print("Solutions = ", I.variety())
# Out:
# Solutions =  [{H_2: 0, H_1: 0, L_2: 0, L_1: 0, S: 300}, {H_2: 0, H_1: 1067037419993/5184619201680, L_2: 0, L_1: 1067037419993/217728604800000, S: 21602580007/3628800000}, {H_2: 2134074899993/10369224001680, H_1: 0, L_2: 2134074899993/870913209600000, L_1: 0, S: 43205100007/7257600000}]

# %%
R_ring_fast.<S, L_1, L_2, H_1, H_2> = PolynomialRing(QQ, order='lex')

alpha_1 = 2
alpha_2 = 3
beta_1 = QQ(8)/1000
beta_2 = QQ(8)/1000
gamma_1 = QQ(1)/21
gamma_2 = QQ(1)/21
iota = 0
N_0 = QQ(300)
mu = QQ(1)/30000
Lambda = QQ(1)/100

D = alpha_1 + alpha_2
R_var_sub = N_0 - S - L_1 - L_2 - H_1 - H_2

dSdt   = Lambda - beta_1*S*H_1 - beta_2*S*H_2 + iota*R_var_sub - mu*S
dL_1dt = (beta_1*S*H_1 - alpha_1*L_1)*D - mu*L_1
dL_2dt = (beta_2*S*H_2 - alpha_2*L_2)*D - mu*L_2
dH_1dt = (alpha_1*L_1 - gamma_1*H_1)*D - mu*H_1
dH_2dt = (alpha_2*L_2 - gamma_2*H_2)*D - mu*H_2

I = ideal([dSdt, dL_1dt, dL_2dt, dH_1dt, dH_2dt])

# # 2. Convert to lex order using the change_ring tool (FGLM algorithm)
# R_ring_solve.<S, L_1, L_2, H_1, H_2> = PolynomialRing(K, order='lex')
# I_lex = I_fast.change_ring(R_ring_solve)


#I_sat = I.saturation(L_1 * L_2 * H_1 * H_2)[0]
#print("Saturated dimension:", I_sat.dimension())
#gb_endemic = I_sat.groebner_basis()
#for p in gb_endemic:
#    print(p)


gb = I.groebner_basis()
#gb = I.variety(Ring=QQbar)
#print(len(gb))
# The last element of 'gb' will be a polynomial purely in H_2.
# You can view the triangular equations here:
#print("Actual Ring:", I.ring())
#print("Dimension:", I.dimension())
#print("Groebner Basis:")
for p in gb:
    print(p)

for poly in gb:
    print(poly)
    print("-" * 20)
# Out:
# S + 5000716669/3500000*H_1 + 7501066669/5250000*H_2 - 300
# L_1 - 16669/700000*H_1
# L_2 - 16669/1050000*H_2
# H_1^2 - 246999283331/1200172000560*H_1
# H_1*H_2
# H_2^2 - 370498933331/1800256000560*H_2
# S + 5000716669/3500000*H_1 + 7501066669/5250000*H_2 - 300
# --------------------
# L_1 - 16669/700000*H_1
# --------------------
# L_2 - 16669/1050000*H_2
# --------------------
# H_1^2 - 246999283331/1200172000560*H_1
# --------------------
# H_1*H_2
# --------------------
# H_2^2 - 370498933331/1800256000560*H_2
# --------------------

# %%
print("Solutions = ", I.variety())
# Out:
# Solutions =  [{H_2: 0, H_1: 0, L_2: 0, L_1: 0, S: 300}, {H_2: 0, H_1: 246999283331/1200172000560, L_2: 0, L_1: 246999283331/50400168000000, S: 5000716669/840000000}, {H_2: 370498933331/1800256000560, H_1: 0, L_2: 370498933331/113400252000000, L_1: 0, S: 7501066669/1260000000}]

# %%
# 1. Define the symbolic variables
H_1, H_2, Lambda, beta_1, beta_2, mu, gamma_1, gamma_2, alpha_1, alpha_2, iota = var('H_1 H_2 Lambda beta_1 beta_2 mu gamma_1 gamma_2 alpha_1 alpha_2 iota')

# 2. Define the equations (implicitly equal to 0, i.e., x + y - 5 = 0)
#eq1 = Lambda - beta_1*S*H_1 - beta_2*S*H_2 - mu*S
#eq2 = beta_1*S*H_1 - w_1*beta_2*L_1*H_2 - alpha_1*L_1 - mu*L_1
#eq3 = beta_2*S*H_2 - w_2*beta_1*L_2*H_1 - alpha_2*L_2 - mu*L_2
#eq4 = alpha_1*L_1 + w_2*beta_2*H_1*L_2 - gamma_1*H_1 - mu*H_1
#eq5 = alpha_2*L_2 + w_1*beta_2*L_1*H_1  - gamma_2*H_2 - mu*H_2
#eq6 = gamma_1*H_1 + gamma_2*H_2 - mu*R


eq1 = (gamma_1 + mu)*(alpha_1 + mu)*(beta_1*H_1 + beta_2*H_2 + mu) == beta_1*alpha_1*(Lambda + iota/(iota+mu)*(gamma_1*H_1 + gamma_2*H_2))
eq2 = (gamma_2 + mu)*(alpha_2 + mu)*(beta_1*H_1 + beta_2*H_2 + mu) == beta_2*alpha_2*(Lambda + iota/(iota+mu)*(gamma_1*H_1 + gamma_2*H_2))


# 3. Solve the system
solutions = solve([eq1, eq2], (H_1, H_2))
print(solutions)
# Output: [(1, 4), (4, 1)]
# Out:
# [
# [H_1 == -(Lambda*beta_2*iota + (Lambda*beta_2 - gamma_2*iota)*mu)/((beta_2*gamma_1 - beta_1*gamma_2)*iota), H_2 == (Lambda*beta_1*iota + (Lambda*beta_1 - gamma_1*iota)*mu)/((beta_2*gamma_1 - beta_1*gamma_2)*iota)]
# ]

# %%
# 1. Define the symbolic variables
H_1, H_2, Lambda, beta_1, beta_2, mu, gamma_1, gamma_2, alpha_1, alpha_2, iota, w_1, w_2 = var('H_1 H_2 Lambda beta_1 beta_2 mu gamma_1 gamma_2 alpha_1 alpha_2 iota w_1 w_2')

# 2. Define the equations (implicitly equal to 0, i.e., x + y - 5 = 0)
#eq1 = Lambda - beta_1*S*H_1 - beta_2*S*H_2 - mu*S
#eq2 = beta_1*S*H_1 - w_1*beta_2*L_1*H_2 - alpha_1*L_1 - mu*L_1
#eq3 = beta_2*S*H_2 - w_2*beta_1*L_2*H_1 - alpha_2*L_2 - mu*L_2
#eq4 = alpha_1*L_1 + w_2*beta_2*H_1*L_2 - gamma_1*H_1 - mu*H_1
#eq5 = alpha_2*L_2 + w_1*beta_2*L_1*H_1  - gamma_2*H_2 - mu*H_2
#eq6 = gamma_1*H_1 + gamma_2*H_2 - mu*R

S == (Lambda + iota*((gamma_1*H_1 + gamma_2*H_2)/(iota + mu)))/(beta_1*H_1 + beta_2*H_2 + mu)

L_1 == (beta_1*S*H_1)/(alpha_1+mu+beta_2*H_2)
L_2 == (beta_2*S*H_2)/(alpha_2+mu+beta_1*H_1)

eq1 = beta_1*S*alpha_1 == (gamma_1+mu-w_1*beta_1*L_2)*(alpha_2+mu+beta_1*H_1)
eq2 =  beta_2*S*alpha_2 == (gamma_2+mu-w_2*beta_2*L_1)*(alpha_1+mu+beta_2*H_2)


# 3. Solve the system
sol1 == solve(eq1, H_1)
#print(len(sol1))
#print(sol1[0])


eq2.subs(sol1[0].rhs())

sol21 == solve(eq2, H_2)
print(sol21)

eq2.subs(sol1[1].rhs())
sol22 == solve(eq2, H_2)
print(sol22)

#solutions = solve([eq1, eq2], (H_1, H_2))
#print(solutions)
# Output: [(1, 4), (4, 1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 27
#      23 #print(len(sol1))
#      24 #print(sol1[0])
#      25
#      26
# ---> 27 eq2.subs(sol1[Integer(0)].rhs())
#      28
#      29 sol21 == solve(eq2, H_2)
#      30 print(sol21)
#
# File sage/symbolic/expression.pyx:5805, in sage.symbolic.expression.Expression.subs()
# -> 5805 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/symbolic/expression.pyx:549, in sage.symbolic.expression._subs_make_dict()
# --> 549 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: not able to determine a substitution from 1/2*(H_2*beta_2*gamma_1*iota*w_1 - (H_2*beta_2 - alpha_1 + alpha_2)*gamma_1*iota - (H_2*beta_2 + alpha_2 + 2*gamma_1 + 2*iota)*mu^2 - 2*mu^3 - ((H_2*beta_2 + alpha_2)*gamma_1 + (H_2*beta_2 + alpha_2 + 2*gamma_1)*iota)*mu - sqrt(H_2^2*beta_2^2*gamma_1^2*iota^2*w_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*(2*(H_2*Lambda*beta_1*beta_2 - H_2*beta_2*gamma_1*iota)*mu^3 + (2*H_2^2*beta_1*beta_2*gamma_1*gamma_2 + 2*H_2*Lambda*beta_1*beta_2*gamma_1 - (H_2^2*beta_2^2 - (H_2*alpha_1 - H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (2*H_2*Lambda*beta_1*beta_2*gamma_1 - 2*H_2*beta_2*gamma_1*iota^2 + (2*H_2^2*beta_1*beta_2*gamma_2 + 4*H_2*Lambda*beta_1*beta_2 - 2*H_2*beta_2*gamma_1^2 - (H_2^2*beta_2^2 + H_2*alpha_2*beta_2)*gamma_1)*iota)*mu^2 + ((2*H_2^2*beta_1*beta_2*gamma_2 + 2*H_2*Lambda*beta_1*beta_2 - 2*H_2*beta_2*gamma_1^2 - (H_2^2*beta_2^2 + H_2*alpha_2*beta_2)*gamma_1)*iota^2 + (2*H_2^2*beta_1*beta_2*gamma_1*gamma_2 + 4*H_2*Lambda*beta_1*beta_2*gamma_1 - (H_2^2*beta_2^2 + H_2*alpha_2*beta_2)*gamma_1^2)*iota)*mu)*w_1))/(beta_1*gamma_1*iota + beta_1*mu^2 + (beta_1*gamma_1 + beta_1*iota)*mu)

# %%
# 1. Declare ALL symbols, including S, L_1, L_2
var('H_1 H_2 Lambda beta_1 beta_2 mu gamma_1 gamma_2 alpha_1 alpha_2 iota w_1 w_2 S L_1 L_2')

# 2. Expressions for S, L_1, L_2 (endemic equilibrium relations)
S_expr   = (Lambda + iota*((gamma_1*H_1 + gamma_2*H_2)/(iota + mu))) / (beta_1*H_1 + beta_2*H_2 + mu)
L_1_expr = (beta_1*S*H_1) / (alpha_1 + mu + beta_2*H_2)
L_2_expr = (beta_2*S*H_2) / (alpha_2 + mu + beta_1*H_1)

# 3. Build eq1, eq2 and substitute S, L_1, L_2 into them
eq1 = (beta_1*S*alpha_1 == (gamma_1 + mu - w_1*beta_1*L_2)*(alpha_2 + mu + beta_1*H_1))
eq2 = (beta_2*S*alpha_2 == (gamma_2 + mu - w_2*beta_2*L_1)*(alpha_1 + mu + beta_2*H_2))

eq1 = eq1.subs(S=S_expr, L_1=L_1_expr, L_2=L_2_expr)
eq2 = eq2.subs(S=S_expr, L_1=L_1_expr, L_2=L_2_expr)

# 4. Solve
sol1 = solve(eq1, H_1)
print(len(sol1))
print(sol1[0])

eq2_case0 = eq2.subs(H_1=sol1[0].rhs())
sol21 = solve(eq2_case0, H_2)
print(sol21)

eq2_case1 = eq2.subs(H_1=sol1[1].rhs())
sol22 = solve(eq2_case1, H_2)
print(sol22)
# Out:
# 2
# H_1 == -1/2*((H_2*beta_2 - alpha_1 + alpha_2)*gamma_1*iota + (H_2*beta_2 + alpha_2 + 2*gamma_1 + 2*iota)*mu^2 + 2*mu^3 + ((H_2*beta_2 + alpha_2)*gamma_1 + (H_2*beta_2 + alpha_2 + 2*gamma_1)*iota)*mu - (H_2*S*beta_1*beta_2*iota + H_2*S*beta_1*beta_2*mu)*w_1 + sqrt((H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + (H_2^2*S^2*beta_1^2*beta_2^2*iota^2 + 2*H_2^2*S^2*beta_1^2*beta_2^2*iota*mu + H_2^2*S^2*beta_1^2*beta_2^2*mu^2)*w_1^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*((H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota^2 + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*mu^3 + ((H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*gamma_1 + 2*(H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota)*mu^2 + ((2*H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - 2*H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota^2)*mu)*w_1))/(beta_1*gamma_1*iota + beta_1*mu^2 + (beta_1*gamma_1 + beta_1*iota)*mu)
# [
# H_2 == -1/2*(beta_1*mu^5 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2 + beta_1*iota)*mu^4 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2)*iota)*mu^3 + ((alpha_1 - alpha_2)*beta_1*gamma_1^2 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2 + (beta_1*gamma_1^2 + ((3*alpha_1 - 2*alpha_2)*beta_1 + alpha_2*beta_2)*gamma_1 + ((alpha_1 - 3*alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2)*iota)*mu^2 + (alpha_2*beta_2*gamma_1^3 + (2*alpha_1 - 3*alpha_2)*beta_1*gamma_1^2*gamma_2)*iota + ((alpha_1 - alpha_2)*beta_1*gamma_1^2*gamma_2 + (((2*alpha_1 - alpha_2)*beta_1 + 2*alpha_2*beta_2)*gamma_1^2 + (3*(alpha_1 - 2*alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2)*iota)*mu + (S*beta_1^2*mu^4 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2 + S*beta_1^2*iota)*mu^3 + (S*alpha_1*beta_1^2*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2)*iota)*mu^2 - (S*alpha_2*beta_1*beta_2*gamma_1^2 - S*alpha_1*beta_1^2*gamma_1*gamma_2)*iota + (S*alpha_1*beta_1^2*gamma_1*gamma_2 + ((S*alpha_1*beta_1^2 - S*alpha_2*beta_1*beta_2)*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2)*iota)*mu)*w_1 + (S*beta_1*beta_2*mu^4 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*iota)*mu^3 + (2*S*alpha_2*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*gamma_1^2 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1)*iota)*mu^2 - (2*S*alpha_1*beta_1^2*gamma_1*gamma_2 - (S*alpha_1 + S*alpha_2)*beta_1*beta_2*gamma_1^2)*iota + (S*alpha_2*beta_1*beta_2*gamma_1^2 + (S*beta_1*beta_2*gamma_1^2 - 2*S*alpha_1*beta_1^2*gamma_2 + (S*alpha_1 + 2*S*alpha_2)*beta_1*beta_2*gamma_1)*iota)*mu + (S^2*beta_1^2*beta_2*mu^3 - 2*(S^2*alpha_1 - S^2*alpha_2)*beta_1^2*beta_2*gamma_1*iota + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1 + S^2*beta_1^2*beta_2*iota)*mu^2 + (2*S^2*alpha_2*beta_1^2*beta_2*gamma_1 + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1)*iota)*mu)*w_1)*w_2 + (S^2*beta_1^2*beta_2*w_1*w_2 - beta_1*gamma_1*gamma_2 - beta_1*mu^2 - (beta_1*gamma_1 + beta_1*gamma_2)*mu)*sqrt((H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + (H_2^2*S^2*beta_1^2*beta_2^2*iota^2 + 2*H_2^2*S^2*beta_1^2*beta_2^2*iota*mu + H_2^2*S^2*beta_1^2*beta_2^2*mu^2)*w_1^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*((H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota^2 + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*mu^3 + ((H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*gamma_1 + 2*(H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota)*mu^2 + ((2*H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - 2*H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta ...
# H_2 == -1/2*(beta_1*mu^5 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2 + beta_1*iota)*mu^4 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2)*iota)*mu^3 + ((alpha_1 - alpha_2)*beta_1*gamma_1^2 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2 + (beta_1*gamma_1^2 + ((3*alpha_1 - 2*alpha_2)*beta_1 + alpha_2*beta_2)*gamma_1 + ((alpha_1 - 3*alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2)*iota)*mu^2 + (alpha_2*beta_2*gamma_1^3 + (2*alpha_1 - 3*alpha_2)*beta_1*gamma_1^2*gamma_2)*iota + ((alpha_1 - alpha_2)*beta_1*gamma_1^2*gamma_2 + (((2*alpha_1 - alpha_2)*beta_1 + 2*alpha_2*beta_2)*gamma_1^2 + (3*(alpha_1 - 2*alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2)*iota)*mu + (S*beta_1^2*mu^4 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2 + S*beta_1^2*iota)*mu^3 + (S*alpha_1*beta_1^2*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2)*iota)*mu^2 - (S*alpha_2*beta_1*beta_2*gamma_1^2 - S*alpha_1*beta_1^2*gamma_1*gamma_2)*iota + (S*alpha_1*beta_1^2*gamma_1*gamma_2 + ((S*alpha_1*beta_1^2 - S*alpha_2*beta_1*beta_2)*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2)*iota)*mu)*w_1 + (S*beta_1*beta_2*mu^4 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*iota)*mu^3 + (2*S*alpha_2*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*gamma_1^2 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1)*iota)*mu^2 - (2*S*alpha_1*beta_1^2*gamma_1*gamma_2 - (S*alpha_1 + S*alpha_2)*beta_1*beta_2*gamma_1^2)*iota + (S*alpha_2*beta_1*beta_2*gamma_1^2 + (S*beta_1*beta_2*gamma_1^2 - 2*S*alpha_1*beta_1^2*gamma_2 + (S*alpha_1 + 2*S*alpha_2)*beta_1*beta_2*gamma_1)*iota)*mu + (S^2*beta_1^2*beta_2*mu^3 - 2*(S^2*alpha_1 - S^2*alpha_2)*beta_1^2*beta_2*gamma_1*iota + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1 + S^2*beta_1^2*beta_2*iota)*mu^2 + (2*S^2*alpha_2*beta_1^2*beta_2*gamma_1 + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1)*iota)*mu)*w_1)*w_2 + (S^2*beta_1^2*beta_2*w_1*w_2 - beta_1*gamma_1*gamma_2 - beta_1*mu^2 - (beta_1*gamma_1 + beta_1*gamma_2)*mu)*sqrt((H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + (H_2^2*S^2*beta_1^2*beta_2^2*iota^2 + 2*H_2^2*S^2*beta_1^2*beta_2^2*iota*mu + H_2^2*S^2*beta_1^2*beta_2^2*mu^2)*w_1^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*((H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota^2 + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*mu^3 + ((H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*gamma_1 + 2*(H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota)*mu^2 + ((2*H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - 2*H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta ...
# ]
# [
# H_2 == -1/2*(beta_1*mu^5 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2 + beta_1*iota)*mu^4 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2)*iota)*mu^3 + ((alpha_1 - alpha_2)*beta_1*gamma_1^2 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2 + (beta_1*gamma_1^2 + ((3*alpha_1 - 2*alpha_2)*beta_1 + alpha_2*beta_2)*gamma_1 + ((alpha_1 - 3*alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2)*iota)*mu^2 + (alpha_2*beta_2*gamma_1^3 + (2*alpha_1 - 3*alpha_2)*beta_1*gamma_1^2*gamma_2)*iota + ((alpha_1 - alpha_2)*beta_1*gamma_1^2*gamma_2 + (((2*alpha_1 - alpha_2)*beta_1 + 2*alpha_2*beta_2)*gamma_1^2 + (3*(alpha_1 - 2*alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2)*iota)*mu + (S*beta_1^2*mu^4 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2 + S*beta_1^2*iota)*mu^3 + (S*alpha_1*beta_1^2*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2)*iota)*mu^2 - (S*alpha_2*beta_1*beta_2*gamma_1^2 - S*alpha_1*beta_1^2*gamma_1*gamma_2)*iota + (S*alpha_1*beta_1^2*gamma_1*gamma_2 + ((S*alpha_1*beta_1^2 - S*alpha_2*beta_1*beta_2)*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2)*iota)*mu)*w_1 + (S*beta_1*beta_2*mu^4 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*iota)*mu^3 + (2*S*alpha_2*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*gamma_1^2 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1)*iota)*mu^2 - (2*S*alpha_1*beta_1^2*gamma_1*gamma_2 - (S*alpha_1 + S*alpha_2)*beta_1*beta_2*gamma_1^2)*iota + (S*alpha_2*beta_1*beta_2*gamma_1^2 + (S*beta_1*beta_2*gamma_1^2 - 2*S*alpha_1*beta_1^2*gamma_2 + (S*alpha_1 + 2*S*alpha_2)*beta_1*beta_2*gamma_1)*iota)*mu + (S^2*beta_1^2*beta_2*mu^3 - 2*(S^2*alpha_1 - S^2*alpha_2)*beta_1^2*beta_2*gamma_1*iota + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1 + S^2*beta_1^2*beta_2*iota)*mu^2 + (2*S^2*alpha_2*beta_1^2*beta_2*gamma_1 + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1)*iota)*mu)*w_1)*w_2 - (S^2*beta_1^2*beta_2*w_1*w_2 - beta_1*gamma_1*gamma_2 - beta_1*mu^2 - (beta_1*gamma_1 + beta_1*gamma_2)*mu)*sqrt((H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + (H_2^2*S^2*beta_1^2*beta_2^2*iota^2 + 2*H_2^2*S^2*beta_1^2*beta_2^2*iota*mu + H_2^2*S^2*beta_1^2*beta_2^2*mu^2)*w_1^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*((H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota^2 + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*mu^3 + ((H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*gamma_1 + 2*(H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota)*mu^2 + ((2*H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - 2*H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta ...
# H_2 == -1/2*(beta_1*mu^5 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2 + beta_1*iota)*mu^4 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2 + ((alpha_1 - alpha_2)*beta_1 + 2*beta_1*gamma_1 + beta_1*gamma_2)*iota)*mu^3 + ((alpha_1 - alpha_2)*beta_1*gamma_1^2 + (2*(alpha_1 - alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2 + (beta_1*gamma_1^2 + ((3*alpha_1 - 2*alpha_2)*beta_1 + alpha_2*beta_2)*gamma_1 + ((alpha_1 - 3*alpha_2)*beta_1 + 2*beta_1*gamma_1)*gamma_2)*iota)*mu^2 + (alpha_2*beta_2*gamma_1^3 + (2*alpha_1 - 3*alpha_2)*beta_1*gamma_1^2*gamma_2)*iota + ((alpha_1 - alpha_2)*beta_1*gamma_1^2*gamma_2 + (((2*alpha_1 - alpha_2)*beta_1 + 2*alpha_2*beta_2)*gamma_1^2 + (3*(alpha_1 - 2*alpha_2)*beta_1*gamma_1 + beta_1*gamma_1^2)*gamma_2)*iota)*mu + (S*beta_1^2*mu^4 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2 + S*beta_1^2*iota)*mu^3 + (S*alpha_1*beta_1^2*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1 + S*beta_1^2*gamma_2)*iota)*mu^2 - (S*alpha_2*beta_1*beta_2*gamma_1^2 - S*alpha_1*beta_1^2*gamma_1*gamma_2)*iota + (S*alpha_1*beta_1^2*gamma_1*gamma_2 + ((S*alpha_1*beta_1^2 - S*alpha_2*beta_1*beta_2)*gamma_1 + (S*alpha_1*beta_1^2 + S*beta_1^2*gamma_1)*gamma_2)*iota)*mu)*w_1 + (S*beta_1*beta_2*mu^4 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*iota)*mu^3 + (2*S*alpha_2*beta_1*beta_2*gamma_1 + S*beta_1*beta_2*gamma_1^2 + (S*alpha_2*beta_1*beta_2 + 2*S*beta_1*beta_2*gamma_1)*iota)*mu^2 - (2*S*alpha_1*beta_1^2*gamma_1*gamma_2 - (S*alpha_1 + S*alpha_2)*beta_1*beta_2*gamma_1^2)*iota + (S*alpha_2*beta_1*beta_2*gamma_1^2 + (S*beta_1*beta_2*gamma_1^2 - 2*S*alpha_1*beta_1^2*gamma_2 + (S*alpha_1 + 2*S*alpha_2)*beta_1*beta_2*gamma_1)*iota)*mu + (S^2*beta_1^2*beta_2*mu^3 - 2*(S^2*alpha_1 - S^2*alpha_2)*beta_1^2*beta_2*gamma_1*iota + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1 + S^2*beta_1^2*beta_2*iota)*mu^2 + (2*S^2*alpha_2*beta_1^2*beta_2*gamma_1 + (2*S^2*alpha_2*beta_1^2*beta_2 + S^2*beta_1^2*beta_2*gamma_1)*iota)*mu)*w_1)*w_2 - (S^2*beta_1^2*beta_2*w_1*w_2 - beta_1*gamma_1*gamma_2 - beta_1*mu^2 - (beta_1*gamma_1 + beta_1*gamma_2)*mu)*sqrt((H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*mu^4 + 2*(2*Lambda*alpha_1*beta_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 2*alpha_1*gamma_1)*iota)*mu^3 + (4*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 + alpha_1^2 - 2*alpha_1*alpha_2 + alpha_2^2 - 2*(H_2*alpha_1 + H_2*alpha_2)*beta_2)*gamma_1^2)*iota^2 + (4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2)*gamma_1^2 + (H_2^2*beta_2^2 - 2*H_2*alpha_2*beta_2 + alpha_2^2 - 4*alpha_1*gamma_1)*iota^2 + 2*(2*H_2*alpha_1*beta_1*gamma_2 + 4*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (2*H_2^2*beta_2^2 - alpha_1*alpha_2 + 2*alpha_2^2 - (H_2*alpha_1 + 4*H_2*alpha_2)*beta_2)*gamma_1)*iota)*mu^2 + (H_2^2*S^2*beta_1^2*beta_2^2*iota^2 + 2*H_2^2*S^2*beta_1^2*beta_2^2*iota*mu + H_2^2*S^2*beta_1^2*beta_2^2*mu^2)*w_1^2 + 2*((2*H_2*alpha_1*beta_1*gamma_2 + 2*Lambda*alpha_1*beta_1 - 2*alpha_1*gamma_1^2 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1)*iota^2 + (2*H_2*alpha_1*beta_1*gamma_1*gamma_2 + 4*Lambda*alpha_1*beta_1*gamma_1 + (H_2^2*beta_2^2 - alpha_1*alpha_2 + alpha_2^2 - (H_2*alpha_1 + 2*H_2*alpha_2)*beta_2)*gamma_1^2)*iota)*mu + 2*((H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota^2 + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*mu^3 + ((H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*gamma_1 + 2*(H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta_2)*iota)*mu^2 + ((2*H_2^2*S*beta_1*beta_2^2 + (H_2*S*alpha_1 - 2*H_2*S*alpha_2)*beta_1*beta_2)*gamma_1*iota + (H_2^2*S*beta_1*beta_2^2 - H_2*S*alpha_2*beta_1*beta ...
# ]

# %%
# 1. Define the symbolic variables
h_1, h_2, lambda_1, lambda_2, w_1, w_2, alpha_1, alpha_2, iota, gamma_1, gamma_2 = var('h_1 h_2 lambda_1 lambda_2 w_1 w_2 alpha_1 alpha_2 iota gamma_1 gamma_2')

# 2. Define the equations (implicitly equal to 0, i.e., x + y - 5 = 0)
#eq1 = Lambda - beta_1*S*H_1 - beta_2*S*H_2 - mu*S
#eq2 = beta_1*S*H_1 - w_1*beta_2*L_1*H_2 - alpha_1*L_1 - mu*L_1
#eq3 = beta_2*S*H_2 - w_2*beta_1*L_2*H_1 - alpha_2*L_2 - mu*L_2
#eq4 = alpha_1*L_1 + w_2*beta_2*H_1*L_2 - gamma_1*H_1 - mu*H_1
#eq5 = alpha_2*L_2 + w_1*beta_2*L_1*H_1  - gamma_2*H_2 - mu*H_2
#eq6 = gamma_1*H_1 + gamma_2*H_2 - mu*R


eq1 = 
eq2 = 


# 3. Solve the system
solutions = solve([eq1, eq2], (h_1, h_2))
print(solutions)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      14 eq2 = alpha_2*lambda_2*(Integer(1) + (iota)/(iota+Integer(1))*(gamma_2*h_2 + gamma_1*h_1)) == (w_2*lambda_2*h_2 + alpha_1+Integer(1))*(lambda_2*h_2+lambda_1*h_1+Integer(1))*(gamma_2+Integer(1)) - w_2*lambda_2*(lambda_1)*(Integer(1) + (iota)/(iota+Integer(1))*(gamma_2*h_2 + gamma_1*h_1))*h_1
#      15
#      16
#      17 # 3. Solve the system
# ---> 18 solutions = solve([eq1, eq2], (h_1, h_2))
#      19 print(solutions)
#
# File /usr/local/sage/src/sage/symbolic/relation.py:1330, in solve(f, explicit_solutions, multiplicities, to_poly_solve, solution_dict, algorithm, domain, *args)
#    1327 m = maxima(f)
#    1329 try:
# -> 1330     s = m.solve(x)
#    1331 except Exception:  # if Maxima gave an error, try its to_poly_solve
#    1332     try:
#
# File /usr/local/sage/src/sage/interfaces/interface.py:698, in InterfaceFunctionElement.__call__(self, *args, **kwds)
#     697 def __call__(self, *args, **kwds):
# --> 698     return self._obj.parent().function_call(self._name, [self._obj] + list(args), kwds)
#
# File /usr/local/sage/src/sage/interfaces/interface.py:616, in Interface.function_call(self, function, args, kwds)
#     612 self._check_valid_function_name(function)
#     613 s = self._function_call_string(function,
#     614                                [s.name() for s in args],
#     615                                ['%s=%s' % (key, value.name()) for key, value in kwds.items()])
# --> 616 return self.new(s)
#
# File /usr/local/sage/src/sage/interfaces/interface.py:381, in Interface.new(self, code)
#     380 def new(self, code):
# --> 381     return self(code)
#
# File /usr/local/sage/src/sage/interfaces/interface.py:294, in Interface.__call__(self, x, name)
#     291         pass
#     293 if isinstance(x, str):
# --> 294     return cls(self, x, name=name)
#     295 try:
#     296     # Special methods do not and should not have an option to
#     297     # set the name directly, as the identifier assigned by the
#     298     # interface should stay consistent. An identifier with a
#     299     # user-assigned name might change its value, so we return a
#     300     # new element.
#     301     result = self._coerce_from_special_method(x)
#
# File /usr/local/sage/src/sage/interfaces/interface.py:732, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     730 else:
#     731     try:
# --> 732         self._name = parent._create(value, name=name)
#     733     except (TypeError, RuntimeError, ValueError) as x:
#     734         raise TypeError(x)
#
# File /usr/local/sage/src/sage/interfaces/maxima_lib.py:627, in MaximaLib._create(self, value, name)
#     625         maxima_eval([[msetq], cadadr("#$%s$#$" % name), value])
#     626     else:
# --> 627         self.set(name, value)
#     628 except RuntimeError as error:
#     629     s = str(error)
#
# File /usr/local/sage/src/sage/interfaces/maxima_lib.py:537, in MaximaLib.set(self, var, value)
#     535     raise TypeError
#     536 cmd = '%s : %s$' % (var, value.rstrip(';'))
# --> 537 self.eval(cmd)
#
# File /usr/local/sage/src/sage/interfaces/maxima_lib.py:483, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     481         line = line[ind_dollar + 1:]
#     482         if statement:
# --> 483             maxima_eval("#$%s$" % statement)
#     484 if not reformat:
#     485     return result
#
# File sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__()
# --> 828 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/libs/ecl.pyx:354, in sage.libs.ecl.ecl_safe_apply()
# --> 354 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt: ECL says: Console interrupt.

# %%
# 1. Declare all variables and parameters
var('h1, h2, l1, l2, g1, g2, a1, a2, w1, w2, iota')

# 2. Define the repeating common term present in both equations
# C = (1 + (iota/(iota+1))*(g1*h1 + g2*h2)) / (l1*h1 + l2*h2 + 1)
common_term = (1 + (iota / (iota + 1)) * (g1 * h1 + g2 * h2)) / (l1 * h1 + l2 * h2 + 1)

# 3. Construct Equation 1
LHS1 = (l1 * common_term) / (w2 * l2 * h2 + a1 + 1)
RHS1 = (g1 + 1 - w1 * l1 * ((l2 * common_term * h2) / (w1 * l1 * h1 + a2 + 1))) / a1
eq1 = LHS1 == RHS1

# 4. Construct Equation 2 (Symmetric case)
LHS2 = (l2 * common_term) / (w1 * l1 * h1 + a2 + 1)
RHS2 = (g2 + 1 - w2 * l2 * ((l1 * common_term * h1) / (w2 * l2 * h2 + a1 + 1))) / a2
eq2 = LHS2 == RHS2

# 5. Define your parameter values here
# Replace these placeholder 1.0 values with your actual parameters
params = {
    l1: 3, l2: 3,   # lambda hat 1 & 2
    g1: 1.0, g2: 1.0,   # gamma hat 1 & 2
    a1: 0.5, a2: 0.5,   # alpha hat 1 & 2
    w1: 0.5, w2: 0.5,
    iota: 0.01
}

#l1, l2 are lambda, g1 g2 are gamma, a1 a2 are alpha

# 6. Substitute parameters into equations
eq1_sub = eq1.subs(params)
eq2_sub = eq2.subs(params)

# 7. Solve the system for h1 and h2
print("Attempting to solve the system analytically...")
solutions = solve([eq1_sub, eq2_sub], h1, h2)

# Print the solutions
for sol in solutions:
    print(sol)
# Out:
# Attempting to solve the system analytically...
# [h1 == -1, h2 == -1]
# [h1 == -1, h2 == -100]
# [h1 == -1/2412*sqrt(742657) - 1109/2412, h2 == -1/2412*sqrt(742657) - 1109/2412]
# [h1 == 1/2412*sqrt(742657) - 1109/2412, h2 == 1/2412*sqrt(742657) - 1109/2412]
# [h1 == -100, h2 == -1]
# [h1 == -2/99*I*sqrt(2222) - 1/3, h2 == 1/106826811894*sqrt(51099716184*I*sqrt(2222) + 3277764556033)*(404*I*sqrt(2222) + 13299) + 18281470/1618588059*I*sqrt(2222) - 45112559/98096246]
# [h1 == 2/99*I*sqrt(2222) - 1/3, h2 == -1/106826811894*(404*I*sqrt(2222) - 13299)*sqrt(-51099716184*I*sqrt(2222) + 3277764556033) - 18281470/1618588059*I*sqrt(2222) - 45112559/98096246]
